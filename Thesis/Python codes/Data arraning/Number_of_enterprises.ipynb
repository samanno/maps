# %%
import pandas as pd
from IPython.display import display

# %%
# List of all 9 provinces
provinces = ['Bologna', 'Ferrara', 'Forlì Cesena', 'Modena', 'Parma', 'Piacenza', 'Ravenna', 'Reggio Emilia', 'Rimini']
abbreviations = ['BO', 'FE', 'FC', 'MO', 'PR', 'PC', 'RA', 'RE', 'RN']

# Load the column names from the Excel file
column_names_file = '/content/drive/MyDrive/Thesis/Python codes/Food Industry Enterprises per Province/Food Industry categories.xlsx'
column_names = pd.read_excel(column_names_file)
column_names = column_names.T
column_names = column_names.iloc[0]

# Create an empty list to store the data frames for each province
df_list = []


for i,province in enumerate(provinces):

    # Path of the Excel file for the current province
    excel_file = f'/content/drive/MyDrive/Thesis/Python codes/Food Industry Enterprises per Province/{province}/{province} - Number of active enterprises.xls.xlsx'
    
    # Load the Excel file using pandas
    df = pd.read_excel(excel_file, header=6)
    df = df.iloc[:, [-1]]
    df = df.drop(0)
    df = df.drop(df.tail(1).index) 
    df = df.T

    # Set the column names of the data frame
    df.columns = column_names

    # Add a new column called 'province' at the beginning of the data frame with the name of the province
    df.insert(0, 'NOME_PRO', province)
    df.insert(1, 'ABB_PRO', abbreviations[i])

    # Append the data frame to the list of data frames
    df_list.append(df)

# Concatenate all the data frames into a single data frame
result = pd.concat(df_list, axis=0, ignore_index=False)

# Replace the NaN with 0
result.fillna(0, inplace=True)

# Display the final result
display(result)

# Set the path and filename for the csv file
Number_of_enterprises = '/content/drive/MyDrive/Thesis/Python codes/Food Industry Enterprises per Province/Number of Enterprises.csv'

# Save the DataFrame to a csv file
result.to_csv(Number_of_enterprises, index=False)
# Out:
# Categories       NOME_PRO ABB_PRO    10: manufacture of food products  \
# totale            Bologna      BO                               616.0
# totale            Ferrara      FE                               304.0
# totale       Forlì Cesena      FC                               393.0
# totale             Modena      MO                               776.0
# totale              Parma      PR                               872.0
# totale           Piacenza      PC                               243.0
# totale            Ravenna      RA                               361.0
# totale      Reggio Emilia      RE                               530.0
# totale             Rimini      RN                               282.0
#
# Categories      101: processing and preserving of meat and production of meat products  \
# totale                                                   29.0
# totale                                                   17.0
# totale                                                   25.0
# totale                                                  133.0
# totale                                                  355.0
# totale                                                   32.0
# totale                                                   14.0
# totale                                                   50.0
# totale                                                   13.0
#
# Categories        1011: processing and preserving of meat  \
# totale                                                8.0
# totale                                                7.0
# totale                                               10.0
# totale                                               51.0
# totale                                               26.0
# totale                                                8.0
# totale                                                6.0
# totale                                               19.0
# totale                                                6.0
#
# Categories        1012: processing and preserving of poultry meat  \
# totale                                                    0.0
# totale                                                    1.0
# totale                                                    5.0
# totale                                                    2.0
# totale                                                    0.0
# totale                                                    1.0
# totale                                                    1.0
# totale                                                    4.0
# totale                                                    0.0
#
# Categories        1013: production of meat and poultry meat products  \
# totale                                                   21.0
# totale                                                    9.0
# totale                                                   10.0
# totale                                                   80.0
# totale                                                  329.0
# totale                                                   23.0
# totale                                                    7.0
# totale                                                   27.0
# totale                                                    7.0
#
# Categories      102: processing and preserving of fish, crustaceans and molluscs  \
# totale                                                    2.0
# totale                                                    3.0
# totale                                                    3.0
# totale                                                    1.0
# totale                                                    5.0
# totale                                                    1.0
# totale                                                    0.0
# totale                                                    0.0
# totale                                                    2.0
#
# Categories        1020: processing and preserving of fish, crustaceans and molluscs  \
# totale                                                    2.0
# totale                                                    3.0
# totale                                                    3.0
# totale                                                    1.0
# totale                                                    5.0
# totale                                                    1.0
# totale                                                    0.0
# totale                                                    0.0
# totale                                                    2.0
#
# Categories      103: processing and preserving of fruit and vegetables  ...  \
# totale                                                   16.0           ...
# totale                                                   13.0           ...
# totale                                                    9.0           ...
# totale                                                   14.0           ...
# totale                                                   19.0           ...
# totale                                                   11.0           ...
# totale                                                   16.0           ...
# totale                                                    8.0           ...
# totale                                                    7.0           ...
#
# Categories        1081: manufacture of sugar  \
# totale                                   2.0
# totale                                   0.0
# totale                                   0.0
# totale                                   0.0
# totale                                   0.0
# totale                                   0.0
# totale                                   0.0
# totale                                   0.0
# totale                                   0.0
#
# Categories        1082: manufacture of cocoa, chocolate and sugar confectionery  \
# totale                                                    4.0
# totale                                                    3.0
# totale                                                    5.0
# totale                                                    5.0
# totale                                                    0.0
# totale                                                    3.0
# totale                                                    3.0
# totale                                                    1.0
# totale                                                    4.0
#
# Categories        1083: processing of tea and coffee  \
# totale                                          45.0
# totale                                           5.0
# totale                                          15.0
# totale                                          23.0
# totale                                          14.0
# totale                                           5.0
# totale                                          14.0
# totale                                          12.0
# totale                                          15.0
#
# Categories        1084: manufacture of condiments and seasonings  \
# totale                                                    4.0
# totale                                                    0.0
# totale                                                    1.0
# totale                                                   64.0
# totale                                                    2.0
# totale                                                    1.0
# totale                                                    1.0
# totale                                                   17.0
# totale                                                    1.0
#
# Categories        1085: manufacture of prepared meals and dishes  \
# totale                                                   22.0
# totale                                                    7.0
# totale                                                    9.0
# totale                                                   18.0
# totale                                                   18.0
# totale                                                   10.0
# totale                                                   12.0
# totale                                                   10.0
# totale                                                    7.0
#
# Categories        1086: manufacture of homogenised food preparations and dietetic food  \
# totale                                                    4.0
# totale                                                    1.0
# totale                                                    0.0
# totale                                                    3.0
# totale                                                    2.0
# totale                                                    0.0
# totale                                                    1.0
# totale                                                    0.0
# totale                                                    3.0
#
# Categories        1089: manufacture of other food products n.e.c.  \
# totale                                                   23.0
# totale                                                    9.0
# totale                                                   17.0
# totale                                                   30.0
# totale                                                   25.0
# totale                                                   12.0
# totale                                                   18.0
# totale                                                   25.0
# totale                                                   33.0
#
# Categories      109: manufacture of prepared animal feeds  \
# totale                                                6.0
# totale                                                5.0
# totale                                               13.0
# totale                                               14.0
# totale                                               13.0
# totale                                                6.0
# totale                                                6.0
# totale                                               24.0
# totale                                                2.0
#
# Categories        1091: manufacture of prepared feeds for farm animals  \
# totale                                                    2.0
# totale                                                    3.0
# totale                                                   12.0
# totale                                                   12.0
# totale                                                   10.0
# totale                                                    6.0
# totale                                                    5.0
# totale                                                   21.0
# totale                                                    2.0
#
# Categories        1092: manufacture of prepared pet foods
# totale                                                4.0
# totale                                                2.0
# totale                                                1.0
# totale                                                2.0
# totale                                                3.0
# totale                                                0.0
# totale                                                1.0
# totale                                                3.0
# totale                                                0.0
#
# [9 rows x 37 columns]
